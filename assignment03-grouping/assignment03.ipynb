# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nba.csv')

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df.shape
# Out:
# (458, 9)

# %%
df.size
# Out:
# 4122

# %%
grouped = df.groupby(df['Height'])

# %%
grouped.get_group('6-1')
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 118    Louis Williams      Los Angeles Lakers    23.0       SG  29.0    6-1
# 121      Eric Bledsoe            Phoenix Suns     2.0       PG  26.0    6-1
# 150       Rajon Rondo        Sacramento Kings     9.0       PG  30.0    6-1
# 180       Mo Williams     Cleveland Cavaliers    52.0       PG  33.0    6-1
# 230    Raymond Felton        Dallas Mavericks     2.0       PG  31.0    6-1
# 244  Patrick Beverley         Houston Rockets     2.0       PG  27.0    6-1
# 262       Mike Conley       Memphis Grizzlies    11.0       PG  28.0    6-1
# 263      Bryce Cotton       Memphis Grizzlies     8.0       PG  23.0    6-1
# 286       Tim Frazier    New Orleans Pelicans     2.0       PG  25.0    6-1
# 318   Dennis Schroder           Atlanta Hawks    17.0       PG  22.0    6-1
# 336      Kemba Walker       Charlotte Hornets    15.0       PG  26.0    6-1
# ...

# %%
df['Age'].value_counts()
# Out:
# 24.0    47
# 25.0    45
# 27.0    41
# 23.0    41
# 26.0    36
# 28.0    31
# 30.0    31
# 29.0    28
# 22.0    26
# 31.0    22
# 21.0    19
# 20.0    19
# 33.0    14
# 32.0    13
# 36.0    10
# 34.0    10
# 35.0     9
# 38.0     4
# 37.0     4
# 40.0     3
# 39.0     2
# 19.0     2
# Name: Age, dtype: int64

# %%
#creating bins randomly select some sample points
bins=[19,25,31,36,40]
labels=['19-24','25-30','31-35','37-40'] #label fot new group
df['AgeGroup']=pd.cut(df['Age'],bins=bins,labels=labels,right=False) #cut is use to select values and create bin

# %%
df
# Out:
#               Name            Team     Number Position        Age Height  \
# 0    Avery Bradley  Boston Celtics   0.000000       PG  25.000000    6-2
# 1      Jae Crowder  Boston Celtics  99.000000       SF  25.000000    6-6
# 2     John Holland  Boston Celtics  30.000000       SG  27.000000    6-5
# 3      R.J. Hunter  Boston Celtics  28.000000       SG  22.000000    6-5
# 4    Jonas Jerebko  Boston Celtics   8.000000       PF  29.000000   6-10
# ..             ...             ...        ...      ...        ...    ...
# 453   Shelvin Mack       Utah Jazz   8.000000       PG  26.000000    6-3
# 454      Raul Neto       Utah Jazz  25.000000       PG  24.000000    6-1
# 455   Tibor Pleiss       Utah Jazz  21.000000        C  26.000000    7-3
# 456    Jeff Withey       Utah Jazz  24.000000        C  26.000000    7-0
# 457            NaN             NaN  17.678337      NaN  26.938731    NaN
#
#          Weight            College        Salary AgeGroup
# ...

# %%
df.groupby('AgeGroup')['Salary'].mean()
# Out:
# AgeGroup
# 19-24    2.761705e+06
# 25-30    5.866171e+06
# 31-35    6.635271e+06
# 37-40    3.897656e+06
# Name: Salary, dtype: float64

# %%
df.groupby('AgeGroup')['Salary'].std()
# Out:
# AgeGroup
# 19-24    3.164929e+06
# 25-30    5.459484e+06
# 31-35    6.238296e+06
# 37-40    5.373672e+06
# Name: Salary, dtype: float64

# %%
df.groupby('AgeGroup')['Salary'].median()
# Out:
# AgeGroup
# 19-24    1.721380e+06
# 25-30    4.050000e+06
# 31-35    4.671342e+06
# 37-40    2.834470e+06
# Name: Salary, dtype: float64

# %%
salaryList = list(df.groupby('AgeGroup')['Salary'])

# %%
salaryList
# Out:
# [('19-24',
#   3       1148640.0
#   6       1170960.0
#   8       1824360.0
#   9       3431040.0
#   10      2569260.0
#             ...
#   446    12000000.0
#   447     1175880.0
#   449     1348440.0
#   452     2239800.0
#   454      900000.0
#   Name: Salary, Length: 154, dtype: float64),
#  ('25-30',
#   0      7.730337e+06
#   1      6.796117e+06
#   2      4.842684e+06
#   4      5.000000e+06
#   5      1.200000e+07
#              ...
#   451    9.813480e+05
#   453    2.433333e+06
#   455    2.900000e+06
#   456    9.472760e+05
#   457    4.842684e+06
#   Name: Salary, Length: 213, dtype: float64),
#  ('31-35',
#   19      6300000.0
#   31      1635476.0
#   33     22875000.0
#   34      7402812.0
#   43       947276.0
#             ...
#   375    13000000.0
#   394     4345000.0
#   413     3750000.0
#   415     3135000.0
#   434     5016000.0
#   Name: Salary, Length: 68, dtype: float64),
#  ('37-40',
#   46     4.842684e+06
#   72     2.900000e+06
# ...
